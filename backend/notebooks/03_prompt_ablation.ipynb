# %% [markdown]
# # 03 Prompt Ablation
#
# Experiment matrix:
# - prompt variants (v1, v2, v3)
# - temperature values
# - optional few-shot examples
#
# Track impact on quality and schema reliability.

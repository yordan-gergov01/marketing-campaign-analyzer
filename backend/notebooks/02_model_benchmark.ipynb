# %% [markdown]
# # 02 Model Benchmark
#
# Compare candidate models by:
# - schema pass rate
# - quality rubric scores
# - latency
# - estimated cost per request
#
# Output: recommendation for production default model.

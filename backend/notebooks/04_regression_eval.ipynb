# %% [markdown]
# # 04 Regression Evaluation
#
# Lock a baseline and compare each code/prompt/model update against it.
#
# Required checks:
# - no schema quality regressions
# - no major latency regressions
# - recommendation quality maintained or improved
